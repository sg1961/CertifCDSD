# %% [markdown]
# # Projet Kayak
# # Module de lancement du scraping des hotels

# %%
# !python kayak_get_hotels.py
# Out:
# 2024-10-13 03:54:45 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2024-10-13 03:54:45 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 23.10.0, Python 3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ], pyOpenSSL 23.2.0 (OpenSSL 1.1.1w  11 Sep 2023), cryptography 41.0.3, Platform macOS-15.0.1-arm64-arm-64bit
# 2024-10-13 03:54:45 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-10-13 03:54:45 [py.warnings] WARNING: /opt/anaconda3/lib/python3.11/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# ...

# %%
import pandas as pd 

dfh = pd.read_json("./data/df_booking_hotels_save.json")

dfh.head(10)
# Out:
#                                          hotel_name  city_id  \
# 0                      Au cœur du centre historique        2
# 1                        Hello Bayeux #2 by Melrose        2
# 2                B&B HOTEL Amiens Centre Cathédrale        6
# 3                                      L'AURE BLEUE        2
# 4                             Hôtel du Marché Paris        5
# 5                                La maison de Tania        9
# 6                       Hotel Viator - Gare de Lyon        5
# 7                            Hôtel Avenir Jonquière        5
# 8         Nice studio in old Cronenbourg with Wi-Fi        8
# 9  Le Coeur, Studio central refait à neuf, au calme       12
#
#                                         hotel_adress  hotel_note  hotel_lat  \
# 0            14 Rue Saint-Loup, 14400 Bayeux, France         9.3  49.274074
# 1         13B Rue des Bouchers, 14400 Bayeux, France         8.4  49.278089
# ...
